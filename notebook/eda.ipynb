# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\saipr\\Intrest_Prediction\\data\\train.csv")

# %%
df.head()
# Out:
#     Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0  10000001                 7,000        < 1 year       Rent        68000.0
# 1  10000002                30,000         4 years   Mortgage            NaN
# 2  10000003                24,725         7 years   Mortgage        75566.4
# 3  10000004                16,000        < 1 year        NaN        56160.0
# 4  10000005                17,000         8 years        Own        96000.0
#
#             Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0              not verified                 car           18.37
# 1         VERIFIED - income  debt_consolidation           14.93
# 2  VERIFIED - income source  debt_consolidation           15.88
# 3  VERIFIED - income source  debt_consolidation           14.34
# 4  VERIFIED - income source  debt_consolidation           22.17
#
#    Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# ...

# %%
df.shape
# Out:
# (164309, 14)

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Loan_Amount_Requested    164309 non-null  object
#  1   Length_Employed          156938 non-null  object
#  2   Home_Owner               138950 non-null  object
#  3   Annual_Income            139207 non-null  float64
#  4   Income_Verified          164309 non-null  object
#  5   Purpose_Of_Loan          164309 non-null  object
#  6   Debt_To_Income           164309 non-null  float64
#  7   Inquiries_Last_6Mo       164309 non-null  int64
#  8   Months_Since_Deliquency  75930 non-null   float64
#  9   Number_Open_Accounts     164309 non-null  int64
#  10  Total_Accounts           164309 non-null  int64
#  11  Gender                   164309 non-null  object
#  12  Interest_Rate            164309 non-null  int64
# dtypes: float64(3), int64(4), object(6)
# ...

# %%
df.select_dtypes(include='number')
# Out:
#         Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# 0             68000.0           18.37                   0
# 1                 NaN           14.93                   0
# 2             75566.4           15.88                   0
# 3             56160.0           14.34                   3
# 4             96000.0           22.17                   1
# ...               ...             ...                 ...
# 164304            NaN           13.56                   0
# 164305            NaN            9.12                   0
# 164306            NaN           18.17                   1
# 164307            NaN           18.75                   1
# 164308            NaN           19.44                   1
#
#         Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  \
# 0                           NaN                     9              14
# 1                          17.0                    12              24
# ...

# %%
df.select_dtypes(include='object')
# Out:
#        Loan_Amount_Requested Length_Employed Home_Owner  \
# 0                      7,000        < 1 year       Rent
# 1                     30,000         4 years   Mortgage
# 2                     24,725         7 years   Mortgage
# 3                     16,000        < 1 year        NaN
# 4                     17,000         8 years        Own
# ...                      ...             ...        ...
# 164304                20,725       10+ years       Rent
# 164305                 6,000         8 years        Own
# 164306                20,250       10+ years   Mortgage
# 164307                10,000         4 years       Rent
# 164308                 9,250       10+ years       Rent
#
#                  Income_Verified     Purpose_Of_Loan  Gender
# 0                   not verified                 car  Female
# 1              VERIFIED - income  debt_consolidation  Female
# 2       VERIFIED - income source  debt_consolidation    Male
# ...

# %%
df.describe()
# Out:
#        Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# count   1.392070e+05   164309.000000       164309.000000
# mean    7.333116e+04       17.207189            0.781698
# std     6.037750e+04        7.845083            1.034747
# min     4.000000e+03        0.000000            0.000000
# 25%     4.500000e+04       11.370000            0.000000
# 50%     6.300000e+04       16.840000            0.000000
# 75%     8.869750e+04       22.780000            1.000000
# max     7.500000e+06       39.990000            8.000000
#
#        Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  \
# count             75930.000000         164309.000000   164309.000000
# mean                 34.229356             11.193818       25.067665
# std                  21.761180              4.991813       11.583067
# min                   0.000000              0.000000        2.000000
# 25%                  16.000000              8.000000       17.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Loan_Amount_Requested Length_Employed Home_Owner    Income_Verified  \
# count                 164309          156938     138950             164309
# unique                  1290              11          4                  3
# top                   10,000       10+ years   Mortgage  VERIFIED - income
# freq                   11622           52915      70345              59421
#
#            Purpose_Of_Loan  Gender
# count               164309  164309
# unique                  14       2
# top     debt_consolidation    Male
# freq                 97101  117176

# %%
df.isnull().sum()
# Out:
# Loan_Amount_Requested          0
# Length_Employed             7371
# Home_Owner                 25359
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan_Amount_Requested', 'Length_Employed', 'Home_Owner',
#        'Annual_Income', 'Income_Verified', 'Purpose_Of_Loan', 'Debt_To_Income',
#        'Inquiries_Last_6Mo', 'Months_Since_Deliquency', 'Number_Open_Accounts',
#        'Total_Accounts', 'Gender', 'Interest_Rate'],
#       dtype='object')

# %%
df.shape
# Out:
# (164309, 13)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['Loan_Amount_Requested'].describe()
# Out:
# count     164309
# unique      1290
# top       10,000
# freq       11622
# Name: Loan_Amount_Requested, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Loan_Amount_Requested    164309 non-null  object
#  1   Length_Employed          156938 non-null  object
#  2   Home_Owner               138950 non-null  object
#  3   Annual_Income            139207 non-null  float64
#  4   Income_Verified          164309 non-null  object
#  5   Purpose_Of_Loan          164309 non-null  object
#  6   Debt_To_Income           164309 non-null  float64
#  7   Inquiries_Last_6Mo       164309 non-null  int64
#  8   Months_Since_Deliquency  75930 non-null   float64
#  9   Number_Open_Accounts     164309 non-null  int64
#  10  Total_Accounts           164309 non-null  int64
#  11  Gender                   164309 non-null  object
#  12  Interest_Rate            164309 non-null  int64
# dtypes: float64(3), int64(4), object(6)
# ...

# %%
df['Loan_Amount_Requested'] = (
    df['Loan_Amount_Requested']
    .str.replace(',', '', regex=False)   
    .astype(float)                       
)

# %%
df['Loan_Amount_Requested'].describe()
# Out:
# count    164309.00000
# mean      14349.33692
# std        8281.86870
# min         500.00000
# 25%        8000.00000
# 50%       12075.00000
# 75%       20000.00000
# max       35000.00000
# Name: Loan_Amount_Requested, dtype: float64

# %%
df['Loan_Amount_Requested'].isnull().sum()
# Out:
# 0

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(x=df['Loan_Amount_Requested'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(x=df['Loan_Amount_Requested'])
# Out:
# <Axes: xlabel='Loan_Amount_Requested', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
sns.boxplot(x=df['Loan_Amount_Requested'])
plt.title('Boxplot of Loan Amount Requested')
plt.xlabel('Loan Amount')
plt.show()

# %%
sns.violinplot(x=df['Loan_Amount_Requested'])
plt.title('Violin Plot of Loan Amount Requested')
plt.show()

# %%
df
# Out:
#         Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0                      7000.0        < 1 year       Rent        68000.0
# 1                     30000.0         4 years   Mortgage            NaN
# 2                     24725.0         7 years   Mortgage        75566.4
# 3                     16000.0        < 1 year        NaN        56160.0
# 4                     17000.0         8 years        Own        96000.0
# ...                       ...             ...        ...            ...
# 164304                20725.0       10+ years       Rent            NaN
# 164305                 6000.0         8 years        Own            NaN
# 164306                20250.0       10+ years   Mortgage            NaN
# 164307                10000.0         4 years       Rent            NaN
# 164308                 9250.0       10+ years       Rent            NaN
#
#                  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# ...

# %%
df[['Loan_Amount_Requested', 'Interest_Rate']].describe()
# Out:
#        Loan_Amount_Requested  Interest_Rate
# count           164309.00000  164309.000000
# mean             14349.33692       2.158951
# std               8281.86870       0.738364
# min                500.00000       1.000000
# 25%               8000.00000       2.000000
# 50%              12075.00000       2.000000
# 75%              20000.00000       3.000000
# max              35000.00000       3.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(
    data=df,
    x='Loan_Amount_Requested',
    col='Interest_Rate',
    kind='kde',  
    height=4,
    aspect=1.2,
    fill=True
)
plt.suptitle("Loan Amount Distribution by Interest Rate Category", y=1.05)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Overlay KDE curves for each interest rate category
for rate in sorted(df['Interest_Rate'].unique()):
    sns.kdeplot(
        df[df['Interest_Rate'] == rate]['Loan_Amount_Requested'],
        label=f'Interest Rate {rate}',
        fill=True,       # Fills the area under the curve
        alpha=0.4        # Transparency
    )

plt.title("Loan Amount Distribution by Interest Rate Category")
plt.xlabel("Loan Amount Requested")
plt.ylabel("Density")
plt.legend(title="Interest Rate")
plt.grid(True)
plt.show()

# %% [markdown]
# | Aspect                  | Insight                                                                                                                                                                  |
# | ----------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | 🔍 Distribution Overlap | Interest Rate 1 & 2 have nearly identical distributions — both concentrated around smaller loan amounts.                                                                 |
# | 💰 High Loan Amounts    | Category 3 uniquely covers a broader range and peaks at **larger loan amounts**, suggesting that **higher loan requests are more likely to be charged higher interest**. |
# | ⚖️ Risk & Pricing       | The shift of Category 3 toward higher amounts may reflect **risk-based pricing** — larger loans are often seen as riskier, hence higher interest.                        |
# | 📈 Distribution Shape   | Right-skewness in all groups shows most borrowers request moderate amounts, but there are **notable outliers or minority segments requesting large sums**.               |

# %%
sns.boxplot(x='Interest_Rate', y='Loan_Amount_Requested', data=df)
plt.title('Loan Amount by Interest Rate Category')
plt.xlabel('Interest Rate Category')
plt.ylabel('Loan Amount Requested')
plt.xticks(rotation=45)
plt.show()

# %%
sns.violinplot(x='Interest_Rate', y='Loan_Amount_Requested', data=df)
plt.title('Loan Amount Distribution by Interest Rate Category')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x='Interest_Rate', y='Loan_Amount_Requested', data=df)
plt.title('Loan Amount by Interest Rate Category')
plt.xlabel('Interest Rate Category')
plt.ylabel('Loan Amount Requested')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('Interest_Rate')['Loan_Amount_Requested'].agg(['count', 'mean', 'median', 'min', 'max'])
# Out:
#                count          mean   median     min      max
# Interest_Rate
# 1              33806  13351.443531  12000.0   500.0  35000.0
# 2              70580  13419.251913  12000.0   500.0  35000.0
# 3              59923  16007.801679  15000.0  1000.0  35000.0

# %%
from scipy.stats import f_oneway

group1 = df[df['Interest_Rate'] == 1]['Loan_Amount_Requested']
group2 = df[df['Interest_Rate'] == 2]['Loan_Amount_Requested']
group3 = df[df['Interest_Rate'] == 3]['Loan_Amount_Requested']

f_stat, p_value = f_oneway(group1, group2, group3)

print("F-statistic:", f_stat)
print("p-value:", p_value)

if p_value > 0.05:
    print("p-value > 0.05: Fail to reject the null hypothesis. No significant difference in loan amount requested among interest rate categories.")
else:
    print("p-value ≤ 0.05: Reject the null hypothesis. There is a significant difference in loan amount requested among interest rate categories.")
# Out:
# F-statistic: 1936.5452716421166
# p-value: 0.0
# p-value ≤ 0.05: Reject the null hypothesis. There is a significant difference in loan amount requested among interest rate categories.

# %% [markdown]
# 📌 Key Insights
#
# 💸 Higher loan amounts are associated with higher interest rates.
#
# Borrowers requesting larger loans are more likely to fall into category 3 (high interest).
#
# ⚠️ Risk-based pricing might be in play — larger loans may indicate higher credit risk, thus attracting higher rates.
#
# 📊 Distribution Spread Matters — category 3 has more variability, suggesting greater inconsistency in borrower profiles or loan purposes.

# %% [markdown]
# 📝 Conclusion Summary
#
# There is a statistically significant and practically meaningful difference in the loan amounts requested across different interest rate categories. Specifically, higher interest rate categories are associated with higher average loan requests.

# %% [markdown]
# Home_Owner

# %%
df['Home_Owner'].value_counts()
# Out:
# Home_Owner
# Mortgage    70345
# Rent        56031
# Own         12525
# Other          49
# Name: count, dtype: int64

# %%
ax=sns.countplot(x=df['Home_Owner'])
for bars in ax.containers:
    ax.bar_label(bars)

plt.title("Distribution of House Owner")
# Out:
# Text(0.5, 1.0, 'Distribution of House Owner')

# %%
df['Home_Owner'].describe()
# Out:
# count       138950
# unique           4
# top       Mortgage
# freq         70345
# Name: Home_Owner, dtype: object

# %%
df['Home_Owner'].isnull().sum()
# Out:
# 25359

# %%
df['Home_Owner'].unique()
# Out:
# array(['Rent', 'Mortgage', nan, 'Own', 'Other'], dtype=object)

# %%
df
# Out:
#         Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0                      7000.0        < 1 year       Rent        68000.0
# 1                     30000.0         4 years   Mortgage            NaN
# 2                     24725.0         7 years   Mortgage        75566.4
# 3                     16000.0        < 1 year        NaN        56160.0
# 4                     17000.0         8 years        Own        96000.0
# ...                       ...             ...        ...            ...
# 164304                20725.0       10+ years       Rent            NaN
# 164305                 6000.0         8 years        Own            NaN
# 164306                20250.0       10+ years   Mortgage            NaN
# 164307                10000.0         4 years       Rent            NaN
# 164308                 9250.0       10+ years       Rent            NaN
#
#                  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# ...

# %%
print(df[['Home_Owner', 'Interest_Rate']].info())

print("Unique values in Home_Owner:", df['Home_Owner'].unique())

print(df['Interest_Rate'].describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Home_Owner     138950 non-null  object
#  1   Interest_Rate  164309 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.5+ MB
# None
# Unique values in Home_Owner: ['Rent' 'Mortgage' nan 'Own' 'Other']
# count    164309.000000
# mean          2.158951
# std           0.738364
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max           3.000000
# Name: Interest_Rate, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Interest_Rate'], kde=True, bins=30)
plt.title('Distribution of Interest Rate')
plt.show()

# %%
ax=sns.countplot(x=df['Interest_Rate'])
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Distribution of Intrest Rate")
# Out:
# Text(0.5, 1.0, 'Distribution of Intrest Rate')

# %%
ct = pd.crosstab(df['Home_Owner'], df['Interest_Rate'])
print(ct)
# Out:
# Interest_Rate      1      2      3
# Home_Owner
# Mortgage       16365  29689  24291
# Other             10     25     14
# Own             2488   5416   4621
# Rent            9719  24637  21675

# %%
ct.plot(kind='bar', stacked=True, figsize=(8, 5), colormap='Set3')
plt.title('Stacked Bar Chart: House Ownership vs Interest Rate')
plt.ylabel('Count')
plt.show()

# %%
ct_pct = ct.div(ct.sum(axis=1), axis=0)
ct_pct.plot(kind='bar', stacked=True, figsize=(8, 5), colormap='Set2')
plt.title('Normalized Stacked Bar Chart (Proportion)')
plt.ylabel('Proportion')
plt.show()

# %%
ct.T.plot(kind='bar', figsize=(8, 5))
plt.title('Grouped Bar Chart: Interest Rate by House Ownership')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns

sns.heatmap(ct, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Heatmap of House Ownership vs Interest Rate')
plt.show()

# %%
sns.countplot(data=df, x='Interest_Rate', hue='Home_Owner')
plt.title('Count Plot: Interest Rate by House Ownership')
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency

ct = pd.crosstab(df['Home_Owner'], df['Interest_Rate'])

chi2, p, dof, expected = chi2_contingency(ct)

print(f"Chi-square statistic: {chi2}")
print(f"Degrees of freedom: {dof}")
print(f"P-value: {p:.4f}")

alpha = 0.05  

if p < alpha:
    print("Result: Reject the null hypothesis.")
    print("Conclusion: There is a statistically significant association between 'House_Owner' and 'Interest_Rate'.")
else:
    print("Result: Fail to reject the null hypothesis.")
    print("Conclusion: There is no statistically significant association between 'House_Owner' and 'Interest_Rate'.")
# Out:
# Chi-square statistic: 707.259445559306
# Degrees of freedom: 6
# P-value: 0.0000
# Result: Reject the null hypothesis.
# Conclusion: There is a statistically significant association between 'House_Owner' and 'Interest_Rate'.

# %% [markdown]
# | Category            | Observations                                                                       |
# | ------------------- | ---------------------------------------------------------------------------------- |
# | **Mortgage**        | Highest volume overall, most concentrated in Interest Rate 2, followed by 3 and 1. |
# | **Rent**            | Second-highest volume, similar pattern to Mortgage.                                |
# | **Own**             | Very small group, but still skewed toward Interest Rate 2.                         |
# | **Other**           | Negligible numbers; not influential in the analysis.                               |
# | **Interest Rate 2** | Most common across all house ownership categories.                                 |

# %% [markdown]
# 📝 Final Summary Conclusion
#
# There is a strong and statistically significant association between house ownership status and interest rate levels. Specifically:
#
# People with a mortgage or who rent are far more likely to fall into Interest Rate 2 or 3 categories.
#
# Homeowners (Own) without a mortgage tend to appear less often and are relatively more stable, but still most commonly experience Interest Rate 2.
#
# The "Other" category is statistically insignificant due to very small counts.

# %% [markdown]
# Gender

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      117176
# Female     47133
# Name: count, dtype: int64

# %%
ax=sns.countplot(x=df['Gender'])
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Distribution of Gender")
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %%
pd.crosstab(df['Gender'], df['Interest_Rate'])
# Out:
# Interest_Rate      1      2      3
# Gender
# Female          9669  20415  17049
# Male           24137  50165  42874

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Gender', hue='Interest_Rate')
plt.title('Interest Rate Distribution by Gender')
plt.show()

# %%
crosstab = pd.crosstab(df['Gender'], df['Interest_Rate'], normalize='index')
crosstab.plot(kind='bar', stacked=True)
plt.title("Proportional Interest Rate by Gender")
plt.ylabel("Proportion")
plt.show()

# %%
from scipy.stats import chi2_contingency

table = pd.crosstab(df['Gender'], df['Interest_Rate'])
chi2, p, dof, expected = chi2_contingency(table)

print("Chi-square statistic:", chi2)
print("p-value:", p)

alpha = 0.05 

if p < alpha:
    print("Result: Reject the null hypothesis.")
    print("Interpretation: There is a significant relationship between Gender and Interest Rate.")
else:
    print("Result: Fail to reject the null hypothesis.")
    print("Interpretation: There is no significant relationship between Gender and Interest Rate.")
# Out:
# Chi-square statistic: 3.6933695301274088
# p-value: 0.1577593094961047
# Result: Fail to reject the null hypothesis.
# Interpretation: There is no significant relationship between Gender and Interest Rate.

# %% [markdown]
# | Aspect               | Insight                                                                          |
# | -------------------- | -------------------------------------------------------------------------------- |
# | **Distribution**     | Males dominate numerically, but proportions are similar.                         |
# | **Proportions**      | Interest Rate distribution is consistent across genders.                         |
# | **Chi-Square Test**  | Confirms the lack of significant association.                                    |
# | **Business Insight** | Gender **does not influence** Interest Rate category assignment in this dataset. |

# %%
df
# Out:
#         Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0                      7000.0        < 1 year       Rent        68000.0
# 1                     30000.0         4 years   Mortgage            NaN
# 2                     24725.0         7 years   Mortgage        75566.4
# 3                     16000.0        < 1 year        NaN        56160.0
# 4                     17000.0         8 years        Own        96000.0
# ...                       ...             ...        ...            ...
# 164304                20725.0       10+ years       Rent            NaN
# 164305                 6000.0         8 years        Own            NaN
# 164306                20250.0       10+ years   Mortgage            NaN
# 164307                10000.0         4 years       Rent            NaN
# 164308                 9250.0       10+ years       Rent            NaN
#
#                  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# ...

# %% [markdown]
# Annual Income

# %%
df['Annual_Income'].describe()
# Out:
# count    1.392070e+05
# mean     7.333116e+04
# std      6.037750e+04
# min      4.000000e+03
# 25%      4.500000e+04
# 50%      6.300000e+04
# 75%      8.869750e+04
# max      7.500000e+06
# Name: Annual_Income, dtype: float64

# %%
df['Annual_Income'].isnull().sum()
# Out:
# 25102

# %%
sns.distplot(x=df['Annual_Income'])
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Annual_Income'], kde=True,bins=100)
plt.title("Distribution of Annual Income")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(x=df['Annual_Income'])
plt.title("Boxplot of Annual Income")
plt.show()

# %%
import numpy as np

sns.histplot(np.log1p(df['Annual_Income']), kde=True)
plt.title("Log-Transformed Distribution of Annual Income")
plt.xlabel("log(Annual Income + 1)")
plt.show()

# %%
median_income = df['Annual_Income'].median()
df['Annual_Income'].fillna(median_income, inplace=True)

# %%
df['Annual_Income'].isnull().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Interest_Rate', y='Annual_Income', data=df)
plt.title('Annual Income by Interest Rate Category')
plt.show()

# %%
sns.violinplot(x='Interest_Rate', y='Annual_Income', data=df)
plt.title('Annual Income Distribution by Interest Rate')
plt.show()

# %%
sns.barplot(x='Interest_Rate', y='Annual_Income', data=df)
plt.title('Median Annual Income by Interest Rate')
plt.show()

# %%
import pandas as pd
from scipy.stats import shapiro, f_oneway, kruskal
import numpy as np

df_clean = df.dropna(subset=['Annual_Income'])

normality_results = {}
normal = True
for name, group in df_clean.groupby('Interest_Rate'):
    income = group['Annual_Income']
    stat, p = shapiro(income.sample(min(5000, len(income)))) 
    normality_results[name] = p
    if p < 0.05:
        normal = False  

print("Shapiro-Wilk Normality Test p-values by Interest Rate group:")
for k, v in normality_results.items():
    print(f"Interest Rate {k}: p = {v:.4f}")

groups = [group['Annual_Income'].values for name, group in df_clean.groupby('Interest_Rate')]

if normal:
    stat, p = f_oneway(*groups)
    print("\nANOVA Test:")
    print(f"F-statistic = {stat:.4f}, p-value = {p:.4f}")
    if p < 0.05:
        print("=> Reject null hypothesis: Mean income differs between interest rate groups.")
    else:
        print("=> Fail to reject null: No significant mean difference.")
else:
    stat, p = kruskal(*groups)
    print("\nKruskal-Wallis Test:")
    print(f"H-statistic = {stat:.4f}, p-value = {p:.4f}")
    if p < 0.05:
        print("=> Reject null hypothesis: Income distribution differs between interest rate groups.")
    else:
        print("=> Fail to reject null: No significant difference in distribution.")
# Out:
# Shapiro-Wilk Normality Test p-values by Interest Rate group:
# Interest Rate 1: p = 0.0000
# Interest Rate 2: p = 0.0000
# Interest Rate 3: p = 0.0000
#
# Kruskal-Wallis Test:
# H-statistic = 1458.9277, p-value = 0.0000
# => Reject null hypothesis: Income distribution differs between interest rate groups.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for rate in sorted(df['Interest_Rate'].dropna().unique()):
    sns.kdeplot(
        data=df[df['Interest_Rate'] == rate]['Annual_Income'].dropna(),
        label=f'Interest Rate {rate}',
        fill=True,
        alpha=0.4
    )

plt.title("Annual Income Distribution by Interest Rate Category")
plt.xlabel("Annual Income")
plt.ylabel("Density")
plt.legend(title="Interest Rate")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for rate in sorted(df['Interest_Rate'].dropna().unique()):
    sns.histplot(
        data=df[df['Interest_Rate'] == rate]['Annual_Income'].dropna(),
        label=f'Interest Rate {rate}',
        kde=False,
        bins=50,
        stat='density',  
        alpha=0.4
    )

plt.title("Annual Income Histogram by Interest Rate Category")
plt.xlabel("Annual Income")
plt.ylabel("Density")
plt.legend(title="Interest Rate")
plt.grid(True)
plt.show()

# %% [markdown]
# | Aspect                       | Insight                                                               |
# | ---------------------------- | --------------------------------------------------------------------- |
# | **Distribution Shape**       | Annual income is highly skewed right across all categories            |
# | **Median Trend**             | Lower interest rates are associated with higher median incomes        |
# | **Statistical Significance** | Kruskal-Wallis confirms the distributions **differ significantly**    |
# | **Business Interpretation**  | Higher-income applicants likely receive more favorable interest rates |

# %% [markdown]
# ✅ Final Conclusion
#
# There is a statistically significant and visually supported relationship between Annual Income and Interest Rate.
# Borrowers with higher income are more likely to receive lower interest rates, possibly due to better creditworthiness or risk profiles.

# %%
df['Total_Accounts'].value_counts()
# Out:
# Total_Accounts
# 21     6137
# 22     6093
# 20     5987
# 18     5973
# 19     5961
#        ...
# 102       1
# 116       1
# 97        1
# 92        1
# 99        1
# Name: count, Length: 100, dtype: int64

# %%
df
# Out:
#         Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0                      7000.0        < 1 year       Rent        68000.0
# 1                     30000.0         4 years   Mortgage        63000.0
# 2                     24725.0         7 years   Mortgage        75566.4
# 3                     16000.0        < 1 year        NaN        56160.0
# 4                     17000.0         8 years        Own        96000.0
# ...                       ...             ...        ...            ...
# 164304                20725.0       10+ years       Rent        63000.0
# 164305                 6000.0         8 years        Own        63000.0
# 164306                20250.0       10+ years   Mortgage        63000.0
# 164307                10000.0         4 years       Rent        63000.0
# 164308                 9250.0       10+ years       Rent        63000.0
#
#                  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

features = ['Debt_To_Income', 'Months_Since_Deliquency', 'Number_Open_Accounts', 'Total_Accounts']


sns.pairplot(df, corner=True, diag_kind='kde', plot_kws={'alpha': 0.5})
plt.suptitle("Pairplot of Numerical Features", y=1.02)
plt.show()

plt.figure(figsize=(12, 8))
for i, feature in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(y=df[feature])
    plt.title(f"Boxplot of {feature}")
    plt.tight_layout()
plt.show()

# 4. Distribution plots
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df[feature], kde=True, bins=30)
    plt.title(f"Distribution of {feature}")
    plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['Debt_To_Income', 'Months_Since_Deliquency', 'Number_Open_Accounts', 'Total_Accounts']

df_subset = df[features].dropna()

plt.figure(figsize=(12, 8))

for i, feature in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df_subset[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['Debt_To_Income', 'Months_Since_Deliquency', 'Number_Open_Accounts', 'Total_Accounts']

df_subset = df[features].dropna()

plt.figure(figsize=(12, 8))

for i, feature in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sns.distplot(df_subset[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel("Density")

plt.tight_layout()
plt.show()
